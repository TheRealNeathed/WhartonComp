# %%
# Import libraries
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import os
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# NLTK VADER for sentiment analysis
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer

finwiz_url = 'https://finviz.com/quote.ashx?t='
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
news_tables = {}

tick1 = input("Pick a first ticker.")
tick2 = input("Pick a second ticker.")
tick3 = input("Pick a third ticker.")

tickers = [tick1, tick2, tick3]

for ticker in tickers:
    url = finwiz_url + ticker
    req = Request(url=url,headers={'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64; rv:20.0) Gecko/20100101 Firefox/20.0'}) 
    response = urlopen(req)    
    # Read the contents of the file into 'html'
    html = BeautifulSoup(response)
    # Find 'news-table' in the Soup and load it into 'news_table'
    news_table = html.find(id='news-table')
    # Add the table to our dictionary
    news_tables[ticker] = news_table
# Out:
# Pick a first ticker.AMZN
# Pick a second ticker.CSCO
# Pick a third ticker.HD

# %%
# Read one single day of headlines for 'AMZN' 
amzn = news_tables[tick1]
# Get all the table rows tagged in HTML with <tr> into 'amzn_tr'
amzn_tr = amzn.findAll('tr')

for i, table_row in enumerate(amzn_tr):
    # Read the text of the element 'a' into 'link_text'
    a_text = table_row.a.text
    # Read the text of the element 'td' into 'data_text'
    td_text = table_row.td.text
    # Print the contents of 'link_text' and 'data_text' 
    print(a_text)
    print(td_text)
    # Exit after printing 4 rows of data
    if i == 3:
        break
# Out:
# 3 Undervalued Stocks to Buy in the Second Half of 2022
# Jul-17-22 10:30AM
# If You Invested $10,000 in Rivian in 2021, This Is How Much You Would Have Today
# 08:10AM
# 2 Warren Buffett Stocks You'll Wish You'd Bought on the Dip
# 06:50AM
# Target, Walmart, Kohl's Have an Answer for Amazon
# Jul-16-22 08:44PM

# %%
parsed_news = []

# Iterate through the news
for file_name, news_table in news_tables.items():
    # Iterate through all tr tags in 'news_table'
    for x in news_table.findAll('tr'):
        # read the text from each tr tag into text
        # get text from a only
        text = x.a.get_text() 
        # splite text in the td tag into a list 
        date_scrape = x.td.text.split()
        # if the length of 'date_scrape' is 1, load 'time' as the only element

        if len(date_scrape) == 1:
            time = date_scrape[0]
            
        # else load 'date' as the 1st element and 'time' as the second    
        else:
            date = date_scrape[0]
            time = date_scrape[1]
        # Extract the ticker from the file name, get the string up to the 1st '_'  
        ticker = file_name.split('_')[0]
        
        # Append ticker, date, time and headline as a list to the 'parsed_news' list
        parsed_news.append([ticker, date, time, text])
        
parsed_news
# Out:
# [['AMZN',
#   'Jul-17-22',
#   '10:30AM',
#   '3 Undervalued Stocks to Buy in the Second Half of 2022'],
#  ['AMZN',
#   'Jul-17-22',
#   '08:10AM',
#   'If You Invested $10,000 in Rivian in 2021, This Is How Much You Would Have Today'],
#  ['AMZN',
#   'Jul-17-22',
#   '06:50AM',
#   "2 Warren Buffett Stocks You'll Wish You'd Bought on the Dip"],
#  ['AMZN',
#   'Jul-16-22',
#   '08:44PM',
#   "Target, Walmart, Kohl's Have an Answer for Amazon"],
#  ['AMZN',
#   'Jul-16-22',
#   '11:15AM',
#   "Can Amazon's Prime Video Finally Convince Consumers to Cut the Cord?"],
#  ['AMZN',
#   'Jul-16-22',
#   '10:00AM',
#   'Grubhubs Rivals Wont Get Eaten by Prime Partnership'],
#  ['AMZN',
#   'Jul-16-22',
#   '09:00AM',
#   'The Metaverse Still Deserves Your Attention. Heres Why.'],
#  ['AMZN',
#   'Jul-16-22',
#   '09:00AM',
#   'Amazon battles to bag reputation for cheapest groceries'],
#  ['AMZN',
#   'Jul-16-22',
#   '08:45AM',
#   'Down But Not Out: Buy These Beaten-Down Dividend Stocks Before They Boom Again'],
#  ['AMZN',
#   'Jul-16-22',
#   '08:00AM',
#   '3 Passive Income Generators Down Between 29% and 36% to Buy On the Dip'],
#  ['AMZN',
#   'Jul-16-22',
#   '12:00AM',
#   '71 Cities and Towns Are Paying Tech Workers to Abandon Silicon Valley. Its Working.'],
#  ['AMZN',
#   'Jul-15-22',
#   '08:05PM',
#   'Amazon Stock: Prime Is About to Get Stickier'],
#  ['AMZN',
#   'Jul-15-22',
#   '07:30PM',
#   'Amazon Expands Drone Delivery Testing to a Big State'],
#  ['AMZN', 'Jul-15-22', '07:13PM', 'Weekly Roundup'],
#  ['AMZN',
#   'Jul-15-22',
#   '06:50PM',
#   'Amazon pauses work on six new U.S. office buildings to weigh hybrid work needs'],
#  ['AMZN',
#   'Jul-15-22',
#   '05:09PM',
#   'NFL considers Apple TV+ as a host for Sunday Ticket streaming'],
#  ['AMZN',
#   'Jul-15-22',
#   '04:15PM',
#   'Stocks end week in the green, financial sector boosted by bank earnings'],
#  ['AMZN',
#   'Jul-15-22',
#   '03:20PM',
#   'Amazon Hits Pause on Office Construction in Tennessee, Washington State as Workers Go Hybrid'],
#  ['AMZN',
#   'Jul-15-22',
#   '03:16PM',
#   'Rivian CEO Hosted an All-Hands Meeting. What Was Discussed.'],
#  ['AMZN', 'Jul-15-22', '01:50PM', 'Why Gap is a $5 stock'],
#  ['AMZN',
#   'Jul-15-22',
#   '12:19PM',
#   'Stock Market Today: Dow Rides Strong Economic Data, Surge in Citi Higher'],
#  ['AMZN', 'Jul-15-22', '12:00PM', 'Why Amazon Stock Rallied on Friday'],
#  ['AMZN',
#   'Jul-15-22',
#   '11:57AM',
#   'I Spent $119 on Amazon Prime Day -- and Saved $51'],
#  ['AMZN',
#   'Jul-15-22',
#   '11:35AM',
#   'Netflix: The good, the bad and the downright ugly as investors brace for Q2 earnings'],
#  ['AMZN',
#   'Jul-15-22',
#   '11:34AM',
#   'Amazons Earnings Outlook Could Be Better Than Feared, Analyst Says'],
#  ['AMZN',
#   'Jul-15-22',
#   '11:08AM',
#   'Digital Transformation? Artificial Intelligence? With These Tools, Even You Could Pull It Off'],
#  ['AMZN',
#   'Jul-15-22',
#   '11:06AM',
#   'Amazon begins cutting private-label selection: Report'],
#  ['AMZN',
#   'Jul-15-22',
#   '10:36AM',
#   'S&P 500 in Rally Mode as Strong Economic Data Eases Recession Fears; Banks Rally'],
#  ['AMZN',
#   'Jul-15-22',
#   '10:27AM',
#   'Amazon Prime Day sales pulled in $4.4 billion, Evercore ISI estimates'],
#  ['AMZN',
#   'Jul-15-22',
#   '10:21AM',
#   'Vexed by Too-High Prices? Try Shopping Online. (Seriously.)'],
#  ['AMZN',
#   'Jul-15-22',
#   '09:21AM',
#   'U.S. retail sales increase 1% in June despite inflation'],
#  ['AMZN',
#   'Jul-15-22',
#   '08:57AM',
#   'Is Amazon Stock a Buy After Its Biggest Prime Day Ever?'],
#  ['AMZN',
#   'Jul-15-22',
#   '08:30AM',
#   '10 Stocks Billionaire David Harding is Buying in Droves'],
#  ['AMZN',
#   'Jul-15-22',
#   '08:24AM',
#   'Google Stock Split Coming Soon As Amazon, Shopify Lack Boost'],
#  ['AMZN',
#   'Jul-15-22',
#   '08:20AM',
#   'Amazon Plans To Recruit 4,000 Workers In Britain: Reuters'],
#  ['AMZN',
#   'Jul-15-22',
#   '08:07AM',
#   '2 Top Buffett Stocks to Buy and Hold for the Long Haul'],
#  ['AMZN', 'Jul-15-22', '07:31AM', 'Better Tech Stock: Apple vs. Microsoft'],
#  ['AMZN',
#   'Jul-15-22',
#   '06:45AM',
#   'This Key Metric Could Make or Break Netflix Stock'],
#  ['AMZN',
#   'Jul-15-22',
#   '06:45AM',
#   '3 Things About Shopify That Smart Investors Know'],
#  ['AMZN',
#   'Jul-15-22',
#   '06:00AM',
#   'Heres Why You Should Consider Investing in Amazon (AMZN)'],
#  ['AMZN',
#   'Jul-15-22',
#   '06:00AM',
#   "Some Major Stocks Are Splitting: Here's When You're Most Likely to Benefit"],
#  ['AMZN',
#   'Jul-15-22',
#   '05:47AM',
#   'The Latest From Big Tech, Including a High-End VR Headset and Lock Screen Monetization'],
#  ['AMZN',
#   'Jul-15-22',
#   '03:51AM',
#   'Online sales nationwide spike during Amazon Prime Day event'],
#  ['AMZN',
#   'Jul-15-22',
#   '03:46AM',
#   'Wells Fargo, BlackRock Fall Premarket; Pinterest, UnitedHealth Rise'],
#  ['AMZN', 'Jul-15-22', '03:29AM', 'Amazon to create 4,000 new UK jobs'],
#  ['AMZN',
#   'Jul-15-22',
#   '02:22AM',
#   'Amazon Has Been Slashing Private-Label Selection Amid Weak Sales'],
#  ['AMZN',
#   'Jul-15-22',
#   '02:00AM',
#   'Homeowners sent free Amazon parcels in brushing scams'],
#  ['AMZN',
#   'Jul-15-22',
#   '01:00AM',
#   'Amazon to employ more people in the UK than the army'],
#  ['AMZN',
#   'Jul-14-22',
#   '09:00PM',
#   "Google Gets Rebuffed by US Regulators, Amazon Plays Nice With EU's"],
#  ['AMZN',
#   'Jul-14-22',
#   '07:01PM',
#   'Amazons UK Recruitment Drive Slows After Rapid Pace of Pandemic'],
#  ['AMZN',
#   'Jul-14-22',
#   '06:38PM',
#   'Amazon pauses office construction at downtown tower to reimagine layout for hybrid work'],
#  ['AMZN',
#   'Jul-14-22',
#   '06:11PM',
#   "Amazon's (AMZN) AWS Gets Picked by Delta, Boosts Clientele"],
#  ['AMZN',
#   'Jul-14-22',
#   '05:14PM',
#   'Amazon Sells More Than 300 Million Items During Prime Day'],
#  ['AMZN',
#   'Jul-14-22',
#   '05:09PM',
#   'Amazon pauses construction on 5 Bellevue towers as it reevaluates design'],
#  ['AMZN',
#   'Jul-14-22',
#   '04:58PM',
#   'Back-to-school spending to reach a new high this year: Deloitte'],
#  ['AMZN',
#   'Jul-14-22',
#   '04:14PM',
#   'Earnings Season Is Coming. Heres What It Means for the Stock Market.'],
#  ['AMZN',
#   'Jul-14-22',
#   '04:12PM',
#   'Congress Wants to Regulate Big Tech. A New Survey Finds Voters Dont Care.'],
#  ['AMZN',
#   'Jul-14-22',
#   '04:04PM',
#   'Consumers are still spending, but inflation is impacting the types of things they buy: ICSC CEO'],
#  ['AMZN',
#   'Jul-14-22',
#   '04:01PM',
#   'Amazon.com to Webcast Second Quarter 2022 Financial Results Conference Call'],
#  ['AMZN',
#   'Jul-14-22',
#   '04:00PM',
#   'Amazon Had the Best Prime Day Ever. Its Not Helping the Stock Price.'],
#  ['AMZN',
#   'Jul-14-22',
#   '03:24PM',
#   'Amazons Ring Gave Surveillance Footage to Authorities 11 Times This Year Without User Consent'],
#  ['AMZN', 'Jul-14-22', '02:37PM', 'Why Canoo Stock Is Up Big Again Today'],
#  ['AMZN',
#   'Jul-14-22',
#   '02:33PM',
#   'Costco will stay hot even as economy slows, Deutsche Bank analyst says'],
#  ['AMZN',
#   'Jul-14-22',
#   '12:14PM',
#   'Amazon gave Ring video doorbell footage to police without a warrant or users consent'],
#  ['AMZN',
#   'Jul-14-22',
#   '12:14PM',
#   'Amazon Prime Days $11.9 Billion Retail\xa0Blitz'],
#  ['AMZN',
#   'Jul-14-22',
#   '12:08PM',
#   'Why Nvidia, Meta, and Amazon Stocks Are Falling Today'],
#  ['AMZN',
#   'Jul-14-22',
#   '11:49AM',
#   'Netflix earnings: What to expect on ads, subscriber growth, and more'],
#  ['AMZN',
#   'Jul-14-22',
#   '11:49AM',
#   'Amazon Prime Day in one chart: Americans stocked up on electronics, household essentials amid inflation'],
#  ['AMZN', 'Jul-14-22', '11:45AM', '3 High-Growth Stocks That Could Soar'],
#  ['AMZN',
#   'Jul-14-22',
#   '11:26AM',
#   'Netflix could be looking for an exit through ad partnership with Microsoft: Analyst'],
#  ['AMZN',
#   'Jul-14-22',
#   '10:41AM',
#   "U.S. online sales during Amazon's Prime Day jump to $12 billion- report"],
#  ['AMZN',
#   'Jul-14-22',
#   '10:37AM',
#   'Amazon Sells More Than 300 Million Items During Prime Day'],
#  ['AMZN',
#   'Jul-14-22',
#   '10:36AM',
#   "U.S. online sales during Amazon's Prime Day jump to $12 bln- report"],
#  ['AMZN', 'Jul-14-22', '10:30AM', '2 Top Cloud Stocks to Buy in July'],
#  ['AMZN',
#   'Jul-14-22',
#   '10:15AM',
#   'Amazon says members bought 300 million items on Prime Day'],
#  ['AMZN',
#   'Jul-14-22',
#   '10:08AM',
#   'If you believe in Amazon, its stock is now a bargain after falling 34% this year'],
#  ['AMZN',
#   'Jul-14-22',
#   '09:27AM',
#   'Colorado businesses say new retail delivery fee hurts them more than Amazon, DoorDash'],
#  ['AMZN',
#   'Jul-14-22',
#   '09:18AM',
#   "Amazon says premium beauty products, Lego sets and Levi's were big sellers during Prime Day"],
#  ['AMZN',
#   'Jul-14-22',
#   '08:58AM',
#   "Why Streaming Won't Always Be a Loss for Amazon"],
#  ['AMZN',
#   'Jul-14-22',
#   '08:51AM',
#   'Amazons Proposed EU Antitrust Settlement Wont Make Tech Regulatory Concerns Go Away'],
#  ['AMZN', 'Jul-14-22', '08:45AM', '10 Best Penny Stocks to Buy in July'],
#  ['AMZN',
#   'Jul-14-22',
#   '08:41AM',
#   'Prime Day 2022 was the Biggest Prime Day Event Ever'],
#  ['AMZN',
#   'Jul-14-22',
#   '08:40AM',
#   'Cathie Woods Fund Starts to Rebound: 10 Stocks to Watch'],
#  ['AMZN',
#   'Jul-14-22',
#   '08:09AM',
#   'Amazon offers concessions to close EU antitrust probes'],
#  ['AMZN',
#   'Jul-14-22',
#   '07:57AM',
#   'Amazon Proposes Settlement of EU Antitrust Charges on Seller Data'],
#  ['AMZN',
#   'Jul-14-22',
#   '07:26AM',
#   'Netflix Surprised Everyone By Picking Microsoft as Its Partner for Ad-Supported Streaming'],
#  ['AMZN',
#   'Jul-14-22',
#   '06:42AM',
#   'Whats Next for the Fed After Inflation Shocks Again'],
#  ['AMZN',
#   'Jul-14-22',
#   '06:25AM',
#   'Amazon proposes concessions as it looks to settle EU antitrust cases: report'],
#  ['AMZN',
#   'Jul-14-22',
#   '06:25AM',
#   'UPDATE 2-Amazon acts to end EU antitrust investigations, avoid fine'],
#  ['AMZN',
#   'Jul-14-22',
#   '06:00AM',
#   'Influencers with Andy Serwer: Roger McNamee'],
#  ['AMZN',
#   'Jul-14-22',
#   '05:54AM',
#   'Amazon offers concessions to end EU antitrust investigation'],
#  ['AMZN',
#   'Jul-14-22',
#   '05:06AM',
#   'Better Stock-Split Stock to Buy Right Now: Amazon, Alphabet, Tesla, or Shopify?'],
#  ['AMZN',
#   'Jul-13-22',
#   '08:26PM',
#   'Amazon has handed Ring video footage to police without user consent'],
#  ['AMZN',
#   'Jul-13-22',
#   '05:45PM',
#   'Amazon (AMZN) Gains As Market Dips: What You Should Know'],
#  ['AMZN',
#   'Jul-13-22',
#   '05:43PM',
#   'Art collective MSCHF sells Eat the Rich popsicles in NYC'],
#  ['AMZN',
#   'Jul-13-22',
#   '05:03PM',
#   'Amazon Prime Day: How shoppers can find the best deals in the final hours'],
#  ['AMZN',
#   'Jul-13-22',
#   '04:39PM',
#   'Job layoffs circulate throughout tech industry'],
#  ['AMZN',
#   'Jul-13-22',
#   '04:31PM',
#   'Stock Market Today: Scorching CPI Sends Stocks on Roller-Coaster Ride'],
#  ['AMZN',
#   'Jul-13-22',
#   '04:20PM',
#   'Amazon Prime Day 2022 is almost over: When does it end, the best deals and more'],
#  ['AMZN',
#   'Jul-13-22',
#   '04:14PM',
#   'Retail stocks lead markets into the close, Google shares sink'],
#  ['CSCO',
#   'Jul-15-22',
#   '08:45AM',
#   'NESsT: Connecting Refugees With Sustainable Employment'],
#  ['CSCO',
#   'Jul-14-22',
#   '05:45PM',
#   'Cisco Systems (CSCO) Dips More Than Broader Markets: What You Should Know'],
#  ['CSCO',
#   'Jul-14-22',
#   '02:02PM',
#   'Cisco Systems Is Not Reacting to Bearish News'],
#  ['CSCO',
#   'Jul-14-22',
#   '01:03PM',
#   'Its a Tech Wreck: Analysts Cut Estimates on Hardware, Software and Internet Stocks'],
#  ['CSCO',
#   'Jul-14-22',
#   '10:07AM',
#   'Cisco stock slides as JP Morgan signals caution on slowing spending'],
#  ['CSCO',
#   'Jul-14-22',
#   '03:19AM',
#   'Extreme Networks (EXTR) Stock Jumps 12.8%: Will It Continue to Soar?'],
#  ['CSCO',
#   'Jul-13-22',
#   '05:50PM',
#   'Cisco Systems (CSCO) Stock Moves -0.37%: What You Should Know'],
#  ['CSCO',
#   'Jul-13-22',
#   '12:20PM',
#   'Is Zoom Stock A Buy Or Sell In Post-Pandemic Economy?'],
#  ['CSCO',
#   'Jul-13-22',
#   '08:45AM',
#   'Creating a Safe, Inclusive Space for LGBTQ Workers'],
#  ['CSCO',
#   'Jul-13-22',
#   '07:32AM',
#   'Caleres and Cisco have been highlighted as Zacks Bull and Bear of the Day'],
#  ['CSCO', 'Jul-13-22', '06:30AM', 'Bear of the Day: Cisco (CSCO)'],
#  ['CSCO',
#   'Jul-12-22',
#   '11:00AM',
#   'Cisco AppDynamics Study: New Class of Post-Pandemic Technology Leaders Emerges to Tackle the Experience Economy'],
#  ['CSCO',
#   'Jul-11-22',
#   '03:47PM',
#   "Cisco Systems, Inc. (NASDAQ:CSCO) Stock's Been Sliding But Fundamentals Look Decent: Will The Market Correct The Share Price In The Future?"],
#  ['CSCO',
#   'Jul-11-22',
#   '07:55AM',
#   'Is Cisco Stock A Buy Or Sell As Investors Mull Possible Large Acquisition?'],
#  ['CSCO',
#   'Jul-08-22',
#   '04:53PM',
#   'Florida man charged with selling fake Cisco equipment in $1 billion scheme'],
#  ['CSCO',
#   'Jul-08-22',
#   '04:50PM',
#   'Florida man charged with selling fake Cisco equipment in $1 bln scheme'],
#  ['CSCO',
#   'Jul-07-22',
#   '05:45PM',
#   'Cisco Systems (CSCO) Gains But Lags Market: What You Should Know'],
#  ['CSCO', 'Jul-07-22', '09:25AM', 'Harnessing the Power of Parked EVs'],
#  ['CSCO',
#   'Jul-06-22',
#   '05:50PM',
#   'Cisco Systems (CSCO) Outpaces Stock Market Gains: What You Should Know'],
#  ['CSCO',
#   'Jul-06-22',
#   '01:17PM',
#   'The 100 Best Companies to Work for Are Great Stocks to Buy in a Crisis'],
#  ['CSCO',
#   'Jul-06-22',
#   '09:59AM',
#   'Dow 30 Stocks Listed and Ranked By 2022 Hedge Fund Bullishness Index'],
#  ['CSCO', 'Jul-05-22', '08:45AM', 'An Open Letter to All Who Seek Safety'],
#  ['CSCO',
#   'Jul-05-22',
#   '03:35AM',
#   'Is it Still Safe to Invest in Cisco Systems (CSCO)?'],
#  ['CSCO',
#   'Jun-30-22',
#   '05:45PM',
#   'Cisco Systems (CSCO) Stock Moves -0.56%: What You Should Know'],
#  ['CSCO',
#   'Jun-30-22',
#   '12:12PM',
#   'Zoom Bets on Corporate Customers to Stem Post-Pandemic Crash'],
#  ['CSCO',
#   'Jun-30-22',
#   '10:30AM',
#   'Should You Buy Blue Chip Stocks Right Now?'],
#  ['CSCO',
#   'Jun-30-22',
#   '10:00AM',
#   'Cisco (CSCO) Expands Tie-Up With GDIT to Offer 5G Solutions'],
#  ['CSCO',
#   'Jun-30-22',
#   '09:55AM',
#   'Cisco Foundation Sparks Innovation by Investing in Promising Solutions to Climate Change'],
#  ['CSCO',
#   'Jun-29-22',
#   '05:50PM',
#   'Cisco Systems (CSCO) Dips More Than Broader Markets: What You Should Know'],
#  ['CSCO',
#   'Jun-28-22',
#   '03:25PM',
#   'Enterprise Tech Shares Could Slide Further in a Recession. Watch These Stocks.'],
#  ['CSCO',
#   'Jun-28-22',
#   '09:55AM',
#   'Cisco (CSCO) Expands Routed Optical Networking Solutions'],
#  ['CSCO',
#   'Jun-28-22',
#   '08:57AM',
#   'Nasdaq Bear Market: 3 Ultra-Cheap, High-Yield Stocks Just Begging to Be Bought'],
#  ['CSCO',
#   'Jun-28-22',
#   '08:45AM',
#   'Updated Cisco Supplier Guide Fosters a Responsible and Sustainable Supply Chain'],
#  ['CSCO',
#   'Jun-28-22',
#   '07:17AM',
#   'Investors Seek More Transparent Tax, Disclosure Norms From Microsoft and Cisco'],
#  ['CSCO',
#   'Jun-27-22',
#   '03:40PM',
#   "Investors Shouldn't Overlook Cisco Systems' (NASDAQ:CSCO) Impressive Returns On Capital"],
#  ['CSCO',
#   'Jun-24-22',
#   '07:38PM',
#   '4 Takeaways From the Barrons Investing in Tech Conference'],
#  ['CSCO',
#   'Jun-24-22',
#   '05:31PM',
#   'An appeals court reversed a $2.75B judgment against Cisco'],
#  ['CSCO',
#   'Jun-24-22',
#   '03:31PM',
#   'Markets see third-best week of 2022, software stocks among biggest gainers'],
#  ['CSCO',
#   'Jun-24-22',
#   '11:47AM',
#   'Next Big Issue for Software Stocks Will Be Sharp Cuts in Earnings Estimates'],
#  ['CSCO',
#   'Jun-24-22',
#   '10:37AM',
#   'Cisco is exiting Russia and Belarus, becoming the last big Silicon Valley company to depart'],
#  ['CSCO',
#   'Jun-23-22',
#   '05:45PM',
#   'Cisco Systems (CSCO) Stock Sinks As Market Gains: What You Should Know'],
#  ['CSCO',
#   'Jun-23-22',
#   '04:21PM',
#   'Cisco Wins Appeal of $1.9 Billion Patent-Infringement Judgment'],
#  ['CSCO',
#   'Jun-23-22',
#   '12:21PM',
#   'WRAPUP 1-Cisco, Nike quit Russia, as pace of Western firms leaving speeds up'],
#  ['CSCO',
#   'Jun-23-22',
#   '10:07AM',
#   'Cisco, Nike quit Russia, as pace of Western firms leaving speeds up'],
#  ['CSCO',
#   'Jun-23-22',
#   '09:49AM',
#   "UPDATE 3-Cisco wins reversal of $2.75 bln damages award because judge's wife owned stock"],
#  ['CSCO',
#   'Jun-23-22',
#   '09:41AM',
#   "Cisco wins reversal of $2.75 billion damages award because judge's wife owned stock"],
#  ['CSCO', 'Jun-23-22', '09:25AM', 'Building Bridges to Career Opportunities'],
#  ['CSCO',
#   'Jun-22-22',
#   '11:54AM',
#   'Zoom (ZM) Launches Zoom Apps SDK, Expands its Portfolio'],
#  ['CSCO',
#   'Jun-22-22',
#   '07:24AM',
#   'The 7 Smartest Nasdaq Stocks to Buy If You Have $250 Right Now'],
#  ['CSCO',
#   'Jun-21-22',
#   '09:00AM',
#   'Cisco Green Team Network: Protecting Our Planet Starts With Us'],
#  ['CSCO',
#   'Jun-20-22',
#   '01:38PM',
#   'Alphabet (GOOGL) Updates Google Meet With Innovative Features'],
#  ['CSCO',
#   'Jun-19-22',
#   '01:55PM',
#   '10 Stocks Donald Yacktman is Selling in 2022'],
#  ['CSCO',
#   'Jun-17-22',
#   '04:13PM',
#   "Here's Where Investors Took Cover in Miserable Week for Tech Stocks"],
#  ['CSCO',
#   'Jun-17-22',
#   '11:30AM',
#   'Cisco (CSCO) Up 3.8% Since Last Earnings Report: Can It Continue?'],
#  ['CSCO',
#   'Jun-17-22',
#   '10:09AM',
#   'Cisco (CSCO) Launches Panoptica & Calisti API-First Solutions'],
#  ['CSCO',
#   'Jun-16-22',
#   '08:45AM',
#   'Reflections During Pride Month: How Cisco Employees Are Creating a More Inclusive Future'],
#  ['CSCO',
#   'Jun-15-22',
#   '11:30AM',
#   "Pharrell Williams' Non-Profit YELLOW and Cisco Unite to Help Reimagine Education"],
#  ['CSCO',
#   'Jun-15-22',
#   '11:30AM',
#   "Cisco's Emerging Technology and Incubation Efforts Deliver Free-Tier, API-First Developer Solutions"],
#  ['CSCO',
#   'Jun-15-22',
#   '10:57AM',
#   'Snowflake (SNOW) Enhances Its Native Python Programmability'],
#  ['CSCO',
#   'Jun-15-22',
#   '09:41AM',
#   'Apples $2 Trillion Market Valuation on Shaky Ground'],
#  ['CSCO',
#   'Jun-15-22',
#   '09:00AM',
#   'Bluescape changes the remote work game with new Webex partnership'],
#  ['CSCO',
#   'Jun-15-22',
#   '07:57AM',
#   'North Carolina should lead in development of artificial intelligence'],
#  ['CSCO',
#   'Jun-15-22',
#   '06:46AM',
#   '7 Seriously Undervalued Dow Stocks to Buy Before Wall Street Catches On'],
#  ['CSCO',
#   'Jun-14-22',
#   '11:30AM',
#   'Cisco Live 2022: New Innovations Fuel the Modern Enterprise'],
#  ['CSCO',
#   'Jun-14-22',
#   '11:30AM',
#   'Cisco Launches AppDynamics Cloud to Enable the Delivery of Exceptional Digital Experiences'],
#  ['CSCO',
#   'Jun-14-22',
#   '11:30AM',
#   'Cisco Delivers Simpler, Smarter Networks with a More Unified Experience'],
#  ['CSCO',
#   'Jun-14-22',
#   '09:59AM',
#   'Partnership to see Emtrain training modules integrated into Cisco platform'],
#  ['CSCO',
#   'Jun-14-22',
#   '09:55AM',
#   'People Behind CSR at Cisco: How JJ Cummings Protects People in Ukraine From Cyberthreats'],
#  ['CSCO',
#   'Jun-14-22',
#   '07:40AM',
#   'Is it Still Safe to Invest in Cisco (CSCO)?'],
#  ['CSCO',
#   'Jun-13-22',
#   '04:15PM',
#   'S&P 500 closes in bear market territory, bond markets move higher'],
#  ['CSCO',
#   'Jun-13-22',
#   '03:01PM',
#   'The total return for Cisco Systems (NASDAQ:CSCO) investors has risen faster than earnings growth over the last five years'],
#  ['CSCO',
#   'Jun-13-22',
#   '12:25PM',
#   'Atlanta beat these two states to land a 700-job Cisco innovation center'],
#  ['CSCO',
#   'Jun-13-22',
#   '09:00AM',
#   'Cisco and Emtrain Announce Partnership to Build a Conscious Workplace Culture for Hybrid Work'],
#  ['CSCO',
#   'Jun-13-22',
#   '08:30AM',
#   'Cisco and Ford CEOs to Discuss the Role of Technology in Transforming the Automotive Industry and How People Use Their Vehicles'],
#  ['CSCO',
#   'Jun-10-22',
#   '07:53PM',
#   'Would Cisco move its HQ to Atlanta? Georgia officlals float that idea'],
#  ['CSCO',
#   'Jun-10-22',
#   '07:51AM',
#   'Cisco had potential headquarters play for Georgia, state officials believed'],
#  ['CSCO',
#   'Jun-09-22',
#   '01:52PM',
#   'The continuing boom in chip sales isnt washing away Wall Streets worries, but AMD could help'],
#  ['CSCO',
#   'Jun-09-22',
#   '09:55AM',
#   'E-Flex: The Role of Vehicle-to-Grid (V2G) Technology in a Sustainable Future'],
#  ['CSCO',
#   'Jun-09-22',
#   '09:40AM',
#   'Cisco Systems Needs to Develop a Base Pattern'],
#  ['CSCO',
#   'Jun-09-22',
#   '09:00AM',
#   'Webex by Cisco Delivers New Technology to Enable Flexibility for the Hybrid Workforce'],
#  ['CSCO',
#   'Jun-09-22',
#   '08:00AM',
#   'Cisco and J.P. Morgan to Host a Tech Talk on Hybrid Work'],
#  ['CSCO',
#   'Jun-09-22',
#   '06:03AM',
#   "Is It Time to Buy the Dow Jones' 3 Worst-Performing Stocks This Year?"],
#  ['CSCO',
#   'Jun-09-22',
#   '05:30AM',
#   'Where Is Cisco Heading After Rough Quarter Earnings?'],
#  ['CSCO',
#   'Jun-08-22',
#   '11:29AM',
#   'Paycom (PAYC) Extends Buyback Plan to Boost Shareholder Value'],
#  ['CSCO',
#   'Jun-08-22',
#   '08:14AM',
#   'The 7 Most Undervalued Long-Term Stocks to Buy Now'],
#  ['CSCO',
#   'Jun-08-22',
#   '06:08AM',
#   '7 Blue-Chip Stocks to Buy Now if You Have $250 to Spend'],
#  ['CSCO',
#   'Jun-07-22',
#   '10:19AM',
#   'Cisco (CSCO) Designing New Security Cloud for IT Ecosystem'],
#  ['CSCO',
#   'Jun-07-22',
#   '08:36AM',
#   'KoboToolbox: Transforming Humanitarian Work Through Voice Capture and Translation'],
#  ['CSCO', 'Jun-06-22', '05:30PM', 'Cisco Declares Quarterly Cash Dividend'],
#  ['CSCO',
#   'Jun-06-22',
#   '11:00AM',
#   'Cisco Unveils Innovations Driving New Security Cloud Strategy'],
#  ['CSCO',
#   'Jun-06-22',
#   '11:00AM',
#   'Cisco Unveils Innovations Driving New Security Cloud Strategy'],
#  ['CSCO',
#   'Jun-04-22',
#   '07:56AM',
#   "Is It Time to Buy the Dow Jones' 3 Worst-Performing May Stocks?"],
#  ['CSCO',
#   'Jun-03-22',
#   '08:26AM',
#   'Driven by Purpose and Our Commitment to Social Justice'],
#  ['CSCO',
#   'Jun-03-22',
#   '08:00AM',
#   'Sandvine Pulls Back From Russia as US, EU\xa0Tighten Control\xa0on Technology It Sells'],
#  ['CSCO',
#   'Jun-02-22',
#   '10:54AM',
#   '6 Undervalued Tech Stocks That Pay Dividends and Buy Back Their Stock'],
#  ['CSCO',
#   'Jun-02-22',
#   '06:01AM',
#   "How Jamie Dimon's 'hurricane' warning compares to what other big-time CEOs are saying"],
#  ['CSCO',
#   'Jun-01-22',
#   '08:26AM',
#   'Cisco Employees From Across the Globe Participated in Our 25th Recycle IT Day'],
#  ['CSCO',
#   'Jun-01-22',
#   '06:23AM',
#   '7 Stocks to Buy and Hold Forever in This Bear Market'],
#  ['CSCO',
#   'May-31-22',
#   '08:00AM',
#   'Cisco Announces June 2022 Events with the Financial Community'],
#  ['CSCO',
#   'May-31-22',
#   '07:01AM',
#   'Fears of a U.S. recession in 2022 are overblown: Goldman Sachs'],
#  ['HD',
#   'Jul-16-22',
#   '09:11AM',
#   '3 Top Discounted Stocks to Buy Now and Hold Forever'],
#  ['HD',
#   'Jul-15-22',
#   '04:27AM',
#   'Is it a Good Choice to Invest in Home Depot (HD)?'],
#  ['HD',
#   'Jul-14-22',
#   '12:15PM',
#   'UniWorld Group, Inc., Connecting Brands With Multicultural Consumers Since 1969 and Partnering With The Home Depot for More Than 20 Years'],
#  ['HD',
#   'Jul-14-22',
#   '10:15AM',
#   "Nasdaq Bear Market: 2 Stocks I'm Buying During a Recession"],
#  ['HD',
#   'Jul-14-22',
#   '08:09AM',
#   "Zacks Industry Outlook Highlights The Home Depot, Lowe's Companies, Builders FirstSource, Beacon Roofing Supply and GMS"],
#  ['HD',
#   'Jul-13-22',
#   '05:45PM',
#   'Home Depot (HD) Gains As Market Dips: What You Should Know'],
#  ['HD',
#   'Jul-13-22',
#   '04:55PM',
#   "3 Recession-Proof Dow Stocks Investors Bought After Today's Red-Hot Inflation Report"],
#  ['HD',
#   'Jul-13-22',
#   '03:33PM',
#   'Home Depot Stock Gets Targeted As A Short Sale Idea; Why This Option Play Can Earn $1,750'],
#  ['HD', 'Jul-13-22', '10:00AM', 'Where to Invest $5,000 for the Next 5 Years'],
#  ['HD',
#   'Jul-13-22',
#   '08:28AM',
#   '5 Stocks to Win in a Thriving Retail Building Products Industry'],
#  ['HD',
#   'Jul-12-22',
#   '10:00AM',
#   'Water Smarter: Simple Tips To Spruce Up Your Sprinkler System'],
#  ['HD',
#   'Jul-11-22',
#   '07:00PM',
#   '7 Blue-Chip Stocks to Buy After Last Months Massive Beating'],
#  ['HD', 'Jul-11-22', '10:11AM', '7 Best Dow Stocks to Buy in July'],
#  ['HD',
#   'Jul-11-22',
#   '07:00AM',
#   'Take the Zacks Approach to Beat the Market: Franklin Covey, Sea Limited, Rollins, Home Depot in Focus'],
#  ['HD',
#   'Jul-11-22',
#   '06:23AM',
#   'The Zacks Analyst Blog Highlights Coca-Cola, Home Depot, Merck and JPMorgan Chase'],
#  ['HD', 'Jul-09-22', '05:17AM', '3 Stocks That Are Great Long-Term Picks'],
#  ['HD',
#   'Jul-08-22',
#   '10:05PM',
#   'Lowes Can Keep Winning Even as Housing Cools'],
#  ['HD', 'Jul-08-22', '09:36PM', 'At UPS, Tattoos Are In, Low Margins Are Out'],
#  ['HD',
#   'Jul-08-22',
#   '09:40AM',
#   'Why Home Depot (HD) is a Top Value Stock for the Long-Term'],
#  ['HD',
#   'Jul-08-22',
#   '07:54AM',
#   'Buy These 4 Blue-Chip Stocks to Strengthen Your Portfolio'],
#  ['HD',
#   'Jul-07-22',
#   '05:45PM',
#   'Home Depot (HD) Gains But Lags Market: What You Should Know'],
#  ['HD', 'Jul-07-22', '11:58AM', 'Got $500? 3 Cheap Stocks to Buy Right Now'],
#  ['HD',
#   'Jul-07-22',
#   '10:49AM',
#   'Why Home Depot, Target, and Walgreens Stocks Have Trailed the Market This Year'],
#  ['HD',
#   'Jul-07-22',
#   '09:00AM',
#   'Investors Heavily Search The Home Depot, Inc. (HD): Here is What You Need to Know'],
#  ['HD',
#   'Jul-06-22',
#   '11:32AM',
#   'Bear market has longer to go amid inflation, strategist says'],
#  ['HD', 'Jul-06-22', '08:27AM', "Why Lowe's Stock Is Down 32% So Far in 2022"],
#  ['HD',
#   'Jul-06-22',
#   '06:30AM',
#   '2 Ways To Take Advantage of the Worst Market in 50 Years'],
#  ['HD',
#   'Jul-05-22',
#   '10:00AM',
#   "The Home Depot's Homer Fund Launches 2022 [email\xa0protected] Employee Assistance Campaign"],
#  ['HD',
#   'Jul-05-22',
#   '03:29AM',
#   'Is it Still Worthy to Invest in Home Depot (HD)?'],
#  ['HD',
#   'Jul-04-22',
#   '10:45AM',
#   '3 No-Brainer Stocks to Buy Even During a Stock Market Plunge'],
#  ['HD',
#   'Jul-01-22',
#   '04:44PM',
#   'Fourth of July deals: Where to save on patio furniture, appliances, and mattresses'],
#  ['HD',
#   'Jun-30-22',
#   '09:35AM',
#   '3 Stocks That Turned $1,000 Into Half a Million Dollars'],
#  ['HD',
#   'Jun-30-22',
#   '06:35AM',
#   'The Zacks Analyst Blog Highlights Meta Platforms, Eli Lilly, The Home Depot, The Boeing Company, Vale'],
#  ['HD',
#   'Jun-29-22',
#   '05:45PM',
#   'Home Depot (HD) Gains As Market Dips: What You Should Know'],
#  ['HD',
#   'Jun-29-22',
#   '02:44PM',
#   'Top Analyst Reports for Meta Platforms, Eli Lilly &  Home Depot'],
#  ['HD',
#   'Jun-29-22',
#   '09:45AM',
#   'Home Depot (HD) is a Top-Ranked Growth Stock: Should You Buy?'],
#  ['HD', 'Jun-29-22', '08:51AM', '3 Top Stocks to Buy During the Sell-Off'],
#  ['HD',
#   'Jun-29-22',
#   '06:34AM',
#   "Should You Buy the Dow Jones' 3 Worst Performing 2022 Stocks?"],
#  ['HD',
#   'Jun-29-22',
#   '05:21AM',
#   '4 Stocks Ken Griffin Bought Hand Over Fist as the Nasdaq Plunged'],
#  ['HD',
#   'Jun-27-22',
#   '12:12PM',
#   "Home Depot's (NYSE:HD) 16% CAGR outpaced the company's earnings growth over the same five-year period"],
#  ['HD',
#   'Jun-25-22',
#   '08:00AM',
#   "3 Dividend Stocks You'll Wish You'd Bought on the Dip"],
#  ['HD',
#   'Jun-24-22',
#   '07:45PM',
#   '7 Blue-Chip Stocks to Avoid in a Bear Market'],
#  ['HD',
#   'Jun-24-22',
#   '07:45PM',
#   '7 Blue-Chip Stocks to Avoid in a Bear Market'],
#  ['HD',
#   'Jun-24-22',
#   '10:07AM',
#   'Is it a Smart Choice to Invest in Home Depot (HD)?'],
#  ['HD',
#   'Jun-23-22',
#   '05:56PM',
#   'Proptech lender Kiavis CEO talks growth amid latest financing in difficult market'],
#  ['HD',
#   'Jun-23-22',
#   '11:20AM',
#   'Home Improvement Retailers Are Still Winning With Analysts, to an Extent'],
#  ['HD',
#   'Jun-23-22',
#   '10:54AM',
#   "Things to Note Ahead of Bed Bath & Beyond's (BBBY) Q1 Earnings"],
#  ['HD',
#   'Jun-23-22',
#   '10:00AM',
#   '3 No-Brainer Stocks to Buy in the Correction'],
#  ['HD',
#   'Jun-23-22',
#   '09:45AM',
#   'The Home Depot Foundation and Osceola Council on Aging Complete Home Renovations for Air Force Veteran in Florida'],
#  ['HD',
#   'Jun-22-22',
#   '05:45PM',
#   'Home Depot (HD) Stock Moves -0.08%: What You Should Know'],
#  ['HD',
#   'Jun-22-22',
#   '04:53PM',
#   'Housing economist: There is a rental housing shortage driving up rent prices'],
#  ['HD', 'Jun-22-22', '12:22PM', "10 Stocks to Buy When They're Down"],
#  ['HD',
#   'Jun-21-22',
#   '11:15AM',
#   '3 Dividend Stocks You Can Safely Hold for Decades'],
#  ['HD',
#   'Jun-21-22',
#   '10:15AM',
#   'With Over Half the U.S. in Drought, Water Conservation Tips for Summer 2022'],
#  ['HD', 'Jun-21-22', '10:00AM', '3 Stocks That Are Easy Wealth Builders'],
#  ['HD',
#   'Jun-20-22',
#   '02:54PM',
#   '10 Dividend Stocks to Buy According to Bryan Hinmons Motley Fool Asset Management'],
#  ['HD',
#   'Jun-20-22',
#   '08:25AM',
#   'The 10 most trusted brands in the U.S., according to Morning Consult'],
#  ['HD',
#   'Jun-17-22',
#   '05:16PM',
#   'Band-Aid, Lysol, UPS among most trusted U.S. brands'],
#  ['HD',
#   'Jun-17-22',
#   '05:13PM',
#   'Home builder Lennar to report earnings on Tuesday'],
#  ['HD',
#   'Jun-16-22',
#   '06:49PM',
#   '7 No-Brainer Blue-Chip Stocks to Buy if You Have Money to Invest'],
#  ['HD',
#   'Jun-16-22',
#   '11:30AM',
#   'Home Depot (HD) Down 1.9% Since Last Earnings Report: Can It Rebound?'],
#  ['HD',
#   'Jun-16-22',
#   '10:00AM',
#   'New Home Depot Survey Reveals the Top Gifts for Dad This Year'],
#  ['HD',
#   'Jun-16-22',
#   '05:00AM',
#   "Suze Orman's advice on buying a house right now"],
#  ['HD',
#   'Jun-15-22',
#   '03:18PM',
#   'Adobe (ADBE) Releases Real-Time CDP With Innovative Features'],
#  ['HD',
#   'Jun-15-22',
#   '09:57AM',
#   'Should You Build Your Portfolio Around This Home Improvement Dividend Stock?'],
#  ['HD',
#   'Jun-14-22',
#   '10:15AM',
#   'Kroger (KR) to Report Q1 Earnings: Key Factors to Note'],
#  ['HD',
#   'Jun-14-22',
#   '10:07AM',
#   '3 Growth Stocks That Raised Their Guidance This Year'],
#  ['HD',
#   'Jun-13-22',
#   '01:05PM',
#   "Why I Will Never Own Lowe's or Home Depot Stock"],
#  ['HD',
#   'Jun-13-22',
#   '09:23AM',
#   '16 Best Beginner Stocks To Invest In Right Now'],
#  ['HD',
#   'Jun-13-22',
#   '08:46AM',
#   "All the Dow's stocks are falling, led by Salesforce and Walt Disney"],
#  ['HD',
#   'Jun-12-22',
#   '03:51PM',
#   'Costco, Home Depot, and 3 Other Retail Stocks to Scoop Up Nowand 1 to Avoid'],
#  ['HD',
#   'Jun-11-22',
#   '11:00AM',
#   'If You Bought 1,000 Shares of This Dividend Stock, Your Passive Income Will Have Grown Nearly Sixfold'],
#  ['HD', 'Jun-10-22', '11:15AM', "Is Home Depot's Premium Price Justified?"],
#  ['HD',
#   'Jun-10-22',
#   '10:40AM',
#   'Home Depot Among B of A Stocks Benefiting From Urbanization'],
#  ['HD',
#   'Jun-10-22',
#   '10:20AM',
#   'All 30 Dow stocks fall, with Goldman and Home Depot stocks the biggest drags'],
#  ['HD',
#   'Jun-10-22',
#   '06:45AM',
#   "Home Depot and Lowe's Just Shed Light on the Broader Economy. Should Investors Worry?"],
#  ['HD',
#   'Jun-10-22',
#   '12:30AM',
#   '5 Retail Stocks Worth a Look, and 1 to Avoid'],
#  ['HD',
#   'Jun-09-22',
#   '04:10PM',
#   'Stocks accelerate losses into the close, all 11 sectors of S&P 500 in the red'],
#  ['HD',
#   'Jun-09-22',
#   '12:31PM',
#   'Salesforce Investors Reject Racial Audit in Activist Loss'],
#  ['HD',
#   'Jun-09-22',
#   '11:05AM',
#   'Home Depot Supplier Showcase: Bonnie Plants Helps Shape the Future of Gardening With a Focus on Giving Back'],
#  ['HD',
#   'Jun-09-22',
#   '10:30AM',
#   'Home Depot Supplier Showcase: Bonnie Plants Helps Shape the Future of Gardening With a Focus on Giving Back'],
#  ['HD',
#   'Jun-09-22',
#   '10:00AM',
#   '3 Blue-Chip Dividend Stocks to Buy on the Dip'],
#  ['HD',
#   'Jun-09-22',
#   '09:20AM',
#   '2 Dividend Stocks That Will Pay You for Life'],
#  ['HD',
#   'Jun-08-22',
#   '11:57AM',
#   'Homebuilder stocks fall as mortgage activity hits 22-year low'],
#  ['HD',
#   'Jun-08-22',
#   '10:27AM',
#   'Stocks: Tesla pops, home builders under pressure, ScottsMiracle-Gro falls'],
#  ['HD',
#   'Jun-07-22',
#   '04:14PM',
#   'Adobe Signs Home Depot As Customer For Personalized Marketing Tool'],
#  ['HD',
#   'Jun-07-22',
#   '10:32AM',
#   'Walmart, Amazon, Home Depot Stock Slump As Target Signals Big Summer Discounts For Overstocked Retailers'],
#  ['HD',
#   'Jun-07-22',
#   '10:31AM',
#   'The Home Depot Foundation Invests To Build and Improve More Than 800 Housing Units for Veterans Facing Homelessness'],
#  ['HD',
#   'Jun-07-22',
#   '10:17AM',
#   'Target leads retail stocks lower, Apple stock climbs, crypto under pressure'],
#  ['HD',
#   'Jun-07-22',
#   '09:23AM',
#   'Reddits WallStreetBets is Buying These 10 Stocks To Survive Upcoming Recession'],
#  ['HD',
#   'Jun-07-22',
#   '08:45AM',
#   'The 5 Biggest Retail Winners and Losers This Earnings Season'],
#  ['HD',
#   'Jun-06-22',
#   '11:42AM',
#   'Home Depot Makes Wells Fargo List of Favored Retail Stocks'],
#  ['HD', 'Jun-06-22', '09:31AM', '10 Best Passive Income Stocks to Buy Now'],
#  ['HD',
#   'Jun-05-22',
#   '05:00AM',
#   '3 Beaten-Down Dividend Stocks That Are Screaming Buys in June'],
#  ['HD', 'Jun-03-22', '09:59AM', '10 Recession-Proof Stocks to Buy Right Now'],
#  ['HD', 'Jun-02-22', '11:55AM', 'Home Depot launches kids line'],
#  ['HD',
#   'Jun-02-22',
#   '11:15AM',
#   'Soaring Inflation Is No Match for Home Depot'],
#  ['HD',
#   'Jun-02-22',
#   '11:07AM',
#   "Does Home Depot's Record Q1 Make the Stock a Buy?"],
#  ['HD',
#   'Jun-02-22',
#   '10:53AM',
#   'Lumber Prices Are Crashing: Is That Good News for Home Depot?'],
#  ['HD',
#   'Jun-02-22',
#   '10:37AM',
#   'This Stock Just Raised Its Sales Forecast, But Does That Make It a Buy?']]

# %%
# Instantiate the sentiment intensity analyzer
vader = SentimentIntensityAnalyzer()

# Set column names
columns = ['ticker', 'date', 'time', 'headline']

# Convert the parsed_news list into a DataFrame called 'parsed_and_scored_news'
parsed_and_scored_news = pd.DataFrame(parsed_news, columns=columns)

# Iterate through the headlines and get the polarity scores using vader
scores = parsed_and_scored_news['headline'].apply(vader.polarity_scores).tolist()

# Convert the 'scores' list of dicts into a DataFrame
scores_df = pd.DataFrame(scores)

# Join the DataFrames of the news and the list of dicts
parsed_and_scored_news = parsed_and_scored_news.join(scores_df, rsuffix='_right')

# Convert the date column from string to datetime
parsed_and_scored_news['date'] = pd.to_datetime(parsed_and_scored_news.date).dt.date

parsed_and_scored_news.head()
# Out:
#   ticker        date     time  \
# 0   AMZN  2022-07-17  10:30AM
# 1   AMZN  2022-07-17  08:10AM
# 2   AMZN  2022-07-17  06:50AM
# 3   AMZN  2022-07-16  08:44PM
# 4   AMZN  2022-07-16  11:15AM
#
#                                             headline   neg    neu    pos  \
# 0  3 Undervalued Stocks to Buy in the Second Half...  0.00  1.000  0.000
# 1  If You Invested $10,000 in Rivian in 2021, Thi...  0.00  1.000  0.000
# 2  2 Warren Buffett Stocks You'll Wish You'd Boug...  0.00  0.769  0.231
# 3  Target, Walmart, Kohl's Have an Answer for Amazon  0.00  0.805  0.195
# 4  Can Amazon's Prime Video Finally Convince Cons...  0.16  0.687  0.153
#
#    compound
# 0    0.0000
# 1    0.0000
# 2    0.4019
# 3    0.1779
# 4   -0.0258

# %%
plt.rcParams['figure.figsize'] = [10, 6]

# Group by date and ticker columns from scored_news and calculate the mean
mean_scores = parsed_and_scored_news.groupby(['ticker','date']).mean()

# Unstack the column ticker
mean_scores = mean_scores.unstack()

# Get the cross-section of compound in the 'columns' axis
mean_scores = mean_scores.xs('compound', axis="columns").transpose()

# Plot a bar chart with pandas
mean_scores.plot(kind = 'bar')
plt.grid()
